# %% [markdown]
# # 4.2 Using matplotlib.pyplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 4.2.1 Plotting a Scatter Plot

# %%
sp_x = [2, 3, 4, 6, 2, 8, 6, 9, 12, 1, 7, 1]
sp_y = [10, 3, 4, 12, 5, 12, 4, 5, 6, 8, 9, 10]
plt.scatter(sp_x, sp_y)
plt.show()

# %% [markdown]
# ## 4.2.2 Plotting a Bar Chart

# %%
b_x = ['0-3', '4-6', '7-9']
b_y = [20, 50, 30]
plt.bar(b_x, b_y)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 4.2.3 Plotting a Histogram

# %%
h_x = [7, 7, 7, 1, 1, 0, 0, 4, 5, 5, 6, 6, 8, 9, 9, 10]
plt.hist(h_x, bins=5)
# Out:
# (array([4., 0., 3., 5., 4.]),
#  array([ 0.,  2.,  4.,  6.,  8., 10.]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ## 4.2.4 Plotting a Line Graph

# %%
l_x = [7, 1, 4, 8, 5, 2, 3]
l_y = [98, 2, 32, 128, 15, 28, 18]

# %%
plt.plot(l_x, l_y)

# %%
zipped = zip(l_x,l_y)
sorted_zip = sorted(zipped)
l_x, l_y = zip(*sorted_zip)

# %%
l_x
# Out:
# (1, 2, 3, 4, 5, 7, 8)

# %%
l_y
# Out:
# (2, 28, 18, 32, 15, 98, 128)

# %%
plt.plot(l_x, l_y)

# %% [markdown]
# # 4.3 Using pandas

# %% [markdown]
# ## 4.3.1 plot()

# %% [markdown]
# Plotting a scatter plot

# %%
sp_x = [2, 3, 4, 6, 2, 8, 6, 9, 12, 1, 7, 1]
sp_y = [10, 3, 4, 12, 5, 12, 4, 5, 6, 8, 9, 10]
df = pd.DataFrame({'A':sp_x, 'B':sp_y})
df.plot(kind='scatter', x='A', y='B')

# %% [markdown]
# Plotting a Bar Chart

# %%
b_x = ['0-3', '4-6', '7-9']
b_y = [20, 50, 30]
df = pd.DataFrame({'A':b_x, 'B':b_y})
df.plot(kind='bar', x='A', y='B')

# %% [markdown]
# Plotting a Line Graph

# %%
l_x = [7, 1, 4, 8, 5, 2, 3]
l_y = [98, 2, 32, 128, 15, 28, 18]
df = pd.DataFrame({'A':l_x, 'B':l_y})
df = df.sort_values(['A'])
df.plot(kind='line', x='A', y='B')

# %% [markdown]
# Plotting a Histogram

# %%
h_x = [7, 7, 7, 1, 1, 0, 0, 4, 5, 5, 6, 6, 8, 9, 9, 10]
df = pd.DataFrame({'A':h_x})
df['A'].plot(kind='hist', bins=5)

# %% [markdown]
# ## 4.3.2 hist()

# %%
df = pd.DataFrame({'A':[2, 3, 1, 1, 4, 4], 'B':[3, 4, 4, 1, 2, 2]})
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4e0f10a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd4e1012090>]],
#       dtype=object)

# %% [markdown]
# # 4.4 Designing our Charts

# %%
x1 = [1, 2, 4, 6, 8, 9, 10]
y1 = [3, 4, 6, 12, 4, 5, 7]
y2 = [5, 1, 2, 6, 8, 9, 1]

plt.figure(figsize=(10, 5))

plt.scatter(x1, y1, color='black', s=50, marker='x', label='With Reward')

plt.scatter(x1, y2, color='darkgray', s=40, marker='o', label='Without Reward')

plt.legend(loc='best')
plt.grid()

plt.xticks([0, 2, 4, 6, 8, 10])
plt.yticks(range(0, 13))

plt.xlabel('Age')
plt.ylabel('Number of Tries')

plt.title("Designing Our Charts")
# Out:
# Text(0.5, 1.0, 'Designing Our Charts')

# %% [markdown]
# # 4.5 The Object-Oriented Interface

# %%
fig, my_ax = plt.subplots()
a = [1, 2, 3, 4]
b = [7, 3, 1, 4]
my_ax.scatter(a, b)

# %%
fig, my_ax2 = plt.subplots()
df = pd.DataFrame({'A':[1, 2, 3, 4], 'B':[7, 3, 1, 4]})
df.plot(kind='scatter', x='A', y='B', ax=my_ax2)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
df = pd.DataFrame({'A':[1, 2, 3, 4], 'B':[4, 2, 3, 1]})

axs[0].scatter(df['A'], df['B'])
axs[1].plot(df['A'], df['B'])

axs[0].set_title('Chart 1')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Number of Tries')
axs[0].set_xticks([1, 2, 3, 4])
axs[0].set_yticks([1, 2, 3, 4])
# Out:
# [<matplotlib.axis.YTick at 0x7fd4e0b31d90>,
#  <matplotlib.axis.YTick at 0x7fd4e0b315d0>,
#  <matplotlib.axis.YTick at 0x7fd4e0b2bc50>,
#  <matplotlib.axis.YTick at 0x7fd4e0a94e50>]
